# %% [markdown]
# # SysML DocGen Jupyter MDK Demo
#
# This notebook demonstrates real in-tool synchronization: run the cells below in Jupyter, then open the SysML DocGen web UI to see the MMS model updated.

# %%
# %load_ext mdk.jupyter.sysml_docgen_notebook
# %sysml_config --server http://127.0.0.1:8000 --project satellite-power --branch main --user engineer
# %sysml_health
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'mdk.jupyter.sysml_docgen_notebook')
#       2 get_ipython().run_line_magic('sysml_config', '--server http://127.0.0.1:8000 --project satellite-power --branch main --user engineer')
#       3 get_ipython().run_line_magic('sysml_health', '')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'mdk'

# %%
# %%sysml_requirement REQ-JUP-001 "Notebook energy margin requirement" --owner "Analysis Team" --satisfy BLK-BATTERY
# Battery SOC shall remain above 30 percent in the worst-case load scenario.

# %%
soc_min = 0.32
assert soc_min >= 0.30

from mdk.jupyter.sysml_docgen_notebook import test_case

test_case(
    "TST-JUP-001",
    "Notebook SOC simulation",
    method="Energy balance simulation executed in Jupyter",
    criterion="SOC_min >= 30%",
    verifies="REQ-JUP-001",
)

# %%
# %sysml_validate
